# %%
# %load ../standard_import.txt
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from IPython.display import Image
from patsy import dmatrices

from sklearn.preprocessing import scale 
from sklearn.grid_search import GridSearchCV
from sklearn import cross_validation
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV, SGDRegressor
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression, PLSSVD
from sklearn.metrics import mean_squared_error

pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_seq_items', None)

# %matplotlib inline

import seaborn as sns
sns.set_context('notebook')
sns.set_style('darkgrid')

# %%
df = pd.read_csv('Mydata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1063 entries, 0 to 1062
# Data columns (total 54 columns):
# Unnamed: 0    1063 non-null int64
# country       1063 non-null object
# househld      1063 non-null int64
# rsex          1063 non-null object
# rage          0 non-null float64
# marstat6      1063 non-null object
# childhh       1063 non-null object
# married       1063 non-null object
# readpap       1063 non-null object
# whpaper       383 non-null object
# webnews       1063 non-null object
# wnwsite1      542 non-null object
# supparty      1059 non-null object
# closepty      688 non-null object
# partyidn      976 non-null object
# partyid1      976 non-null object
# politics      1063 non-null object
# soctrust      1052 non-null object
# ecpolicy      974 non-null object
# govtrust      1057 non-null object
# mpstrust      1058 non-null object
# conlabdf      1020 non-null object
# spend1        1058 non-null object
# dole          1029 non-null object
# taxspend      1050 non-null object
# incomgap      1035 non-null object
# ub1poor       937 non-null object
# ccbeliev      1040 non-null object
# letin         1053 non-null object
# miecono       1051 non-null object
# micultur      1052 non-null object
# reasmig       547 non-null object
# asastay       1042 non-null object
# friendob      1058 non-null object
# raceori3      1063 non-null object
# religion      1058 non-null object
# hedqual       982 non-null object
# rearnd        534 non-null object
# welffeet      883 non-null object
# forgrel1      871 non-null object
# forgrel2      859 non-null object
# forgrel4      861 non-null object
# forgrel5      862 non-null object
# mnntpowr      904 non-null object
# unionsa       1060 non-null object
# reconact      1063 non-null object
# natbrit       747 non-null object
# nateng        575 non-null object
# nateuro       122 non-null object
# natscot       82 non-null object
# natwelsh      49 non-null object
# natni         7 non-null object
# natasia       21 non-null object
# natafric      6 non-null object
# dtypes: float64(1), int64(2), object(51)
# memory usage: 448.5+ KB

# %%
df.head(10)
# Out:
#    Unnamed: 0   country  househld    rsex  rage  \
# 0           1   England         5    Male   NaN
# 1           2  Scotland         1    Male   NaN
# 2           3   England         5  Female   NaN
# 3           4     Wales         1  Female   NaN
# 4           5   England         3  Female   NaN
# 5           6     Wales         7  Female   NaN
# 6           7   England         4    Male   NaN
# 7           8   England         2    Male   NaN
# 8           9     Wales         1    Male   NaN
# 9          10   England         3  Female   NaN
#
#                                             marstat6 childhh  \
# 0                                            Married     Yes
# 1                                            Married      No
# 2                                            Married     Yes
# 3               Divorced/dissolved civil partnership      No
# 4                                            Married      No
# 5                              Living with a partner     Yes
# 6                                            Married     Yes
# 7                                            Married      No
# 8  Single (never married/never in a civil partner...      No
# 9  Single (never married/never in a civil partner...     Yes
#
#                      married readpap  \
# 0  Married/living as married     Yes
# 1  Married/living as married     Yes
# 2  Married/living as married      No
# 3         Separated/divorced      No
# 4  Married/living as married      No
# 5  Married/living as married     Yes
# 6  Married/living as married      No
# 7  Married/living as married      No
# 8              Never married      No
# 9              Never married      No
#
#                                              whpaper  \
# 0                              The Sun/ Scottish Sun
# 1  Other Irish/Northern Irish/Scottish/Welsh, reg...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                      Daily Mirror/ Scottish Mirror
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                         webnews                           wnwsite1 supparty  \
# 0           Several times a day  Other - UK site (PLEASE WRITE IN)       No
# 1                         Never                                NaN      Yes
# 2          Several times a week                           BBC News       No
# 3  Less often than once a month  Other - UK site (PLEASE WRITE IN)       No
# 4                     Every day              The Sun/Sun on Sunday       No
# 5                         Never                                NaN       No
# 6                     Every day  Other - General (PLEASE WRITE IN)       No
# 7           Several times a day                           BBC News      Yes
# 8                     Every day                           BBC News       No
# 9                     Every day                           Sky News       No
#
#   closepty                              partyidn  \
# 0      Yes                                Labour
# 1      NaN                          Conservative
# 2      Yes                                Labour
# 3       No                                  None
# 4      Yes                      Liberal Democrat
# 5       No                                  None
# 6      Yes                                Labour
# 7      NaN  UK Independence Party (UKIP)/Veritas
# 8       No                                   NaN
# 9       No                                Labour
#
#                                partyid1          politics  \
# 0                                Labour             some,
# 1                          Conservative      quite a lot,
# 2                                Labour  or, none at all?
# 3                                  None  or, none at all?
# 4                      Liberal Democrat      quite a lot,
# 5                                  None  or, none at all?
# 6                                Labour  or, none at all?
# 7  UK Independence Party (UKIP)/Veritas      quite a lot,
# 8                                   NaN             some,
# 9                                Labour  or, none at all?
#
#                                       soctrust  \
# 0  Can t be too careful in dealing with people
# 1  Can t be too careful in dealing with people
# 2  Can t be too careful in dealing with people
# 3                   Most people can be trusted
# 4  Can t be too careful in dealing with people
# 5                   Most people can be trusted
# 6  Can t be too careful in dealing with people
# 7                   Most people can be trusted
# 8  Can t be too careful in dealing with people
# 9  Can t be too careful in dealing with people
#
#                                             ecpolicy               govtrust  \
# 0  to stay in the EU and try to reduce the EU s p...           Almost never
# 1                                                NaN       Most of the time
# 2                                                NaN           Almost never
# 3                                                NaN  Only some of the time
# 4                       to leave the European Union,           Almost never
# 5                       to leave the European Union,           Almost never
# 6  or, to work for the formation of a single Euro...  Only some of the time
# 7  to stay in the EU and try to reduce the EU s p...           Almost never
# 8  to stay in the EU and try to reduce the EU s p...  Only some of the time
# 9                       to leave the European Union,           Almost never
#
#                 mpstrust                                       conlabdf  \
# 0           Almost never                               some difference,
# 1       Most of the time                               some difference,
# 2           Almost never                       or, not much difference?
# 3  Only some of the time                                            NaN
# 4           Almost never                       or, not much difference?
# 5           Almost never                       or, not much difference?
# 6  Only some of the time  ... there is a great difference between them,
# 7           Almost never                               some difference,
# 8  Only some of the time                       or, not much difference?
# 9           Almost never                       or, not much difference?
#
#       spend1                          dole  \
# 0     Health                     (Neither)
# 1  Education                     (Neither)
# 2     Health    too low and cause hardship
# 3     Health       Other answer (WRITE IN)
# 4     Health  too high and discourage work
# 5     Health  too high and discourage work
# 6  Education  too high and discourage work
# 7  Education  too high and discourage work
# 8     Health  too high and discourage work
# 9     Health  too high and discourage work
#
#                                             taxspend      incomgap  \
# 0  Increase taxes and spend more on health, educa...     too large
# 1  Keep taxes and spending on these services at s...  about right,
# 2  Keep taxes and spending on these services at s...     too large
# 3                                             (None)     too large
# 4  Keep taxes and spending on these services at s...     too large
# 5  Increase taxes and spend more on health, educa...     too large
# 6  Keep taxes and spending on these services at s...     too large
# 7  Reduce taxes and spend less on health, educati...     too large
# 8  Increase taxes and spend more on health, educa...     too large
# 9  Keep taxes and spending on these services at s...     too large
#
#                                 ub1poor  \
# 0                           is hard up,
# 1                           is hard up,
# 2                has enough to live on,
# 3                has enough to live on,
# 4  ... has more than enough to live on,
# 5                has enough to live on,
# 6                           is hard up,
# 7                           is hard up,
# 8                has enough to live on,
# 9                has enough to live on,
#
#                                             ccbeliev  \
# 0  I believe that climate change is taking place ...
# 1  I believe that climate change is taking place ...
# 2  I believe that climate change is taking place ...
# 3  I believe that climate change is taking place ...
# 4  I believe that climate change is taking place ...
# 5  I believe that climate change is taking place ...
# 6  I believe that climate change is taking place ...
# 7  I believe that climate change is taking place ...
# 8  I believe that climate change is taking place ...
# 9  I believe that climate change is taking place ...
#
#                       letin                        miecono  \
# 0             Reduced a lot                    5 - Neither
# 1             Reduced a lot                              6
# 2             Reduced a lot  0 - Extremely bad for economy
# 3  Remain the same as it is                              4
# 4             Reduced a lot                              1
# 5             Reduced a lot                              3
# 6             Reduced a lot                              6
# 7          Reduced a little                              6
# 8  Remain the same as it is                              7
# 9             Reduced a lot  0 - Extremely bad for economy
#
#                        micultur  \
# 0                             6
# 1                             4
# 2  0 - Cultural life undermined
# 3                             4
# 4                             1
# 5                             2
# 6                             3
# 7                             7
# 8                   5 - Neither
# 9                             2
#
#                                              reasmig  \
# 0                                                NaN
# 1                                                NaN
# 2                Refugees claiming asylum in Britain
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Coming to work in Britain from countries insid...
# 8            Coming to study in British universities
# 9                                                NaN
#
#                       asastay         friendob              raceori3  \
# 0                       Agree  No, none at all  WHITE: of any origin
# 1  Neither agree nor disagree       Yes, a few  WHITE: of any origin
# 2           Disagree strongly  No, none at all  WHITE: of any origin
# 3                       Agree  No, none at all  WHITE: of any origin
# 4                       Agree     Yes, several  WHITE: of any origin
# 5                    Disagree  No, none at all  WHITE: of any origin
# 6                       Agree  No, none at all  WHITE: of any origin
# 7              Agree strongly     Yes, several  WHITE: of any origin
# 8                       Agree     Yes, several  WHITE: of any origin
# 9           Disagree strongly         Yes, one  WHITE: of any origin
#
#                           religion           hedqual               rearnd  \
# 0                      No religion  O level or equiv  £1,301 - 1,600 p.m.
# 1  Presbyterian/Church of Scotland  O level or equiv                  NaN
# 2       Church of England/Anglican      CSE or equiv      £431 - 780 p.m.
# 3                      No religion  O level or equiv      £431 - 780 p.m.
# 4                      No religion               NaN  Less than £430 p.m.
# 5                      No religion  No qualification                  NaN
# 6                      No religion            Degree  £1,801 - 2,200 p.m.
# 7                   Roman Catholic            Degree  £3,601 or more p.m.
# 8                      No religion  O level or equiv  £1,301 - 1,600 p.m.
# 9                      No religion  A level or equiv  Less than £430 p.m.
#
#                      welffeet                    forgrel1  \
# 0                    Disagree                       Agree
# 1                       Agree  Neither agree nor disagree
# 2              Agree strongly              Agree strongly
# 3  Neither agree nor disagree  Neither agree nor disagree
# 4              Agree strongly                       Agree
# 5           Disagree strongly              Agree strongly
# 6  Neither agree nor disagree                       Agree
# 7                    Disagree                    Disagree
# 8  Neither agree nor disagree  Neither agree nor disagree
# 9              Agree strongly  Neither agree nor disagree
#
#                      forgrel2                    forgrel4  \
# 0  Neither agree nor disagree                    Disagree
# 1                    Disagree                       Agree
# 2              Agree strongly                       Agree
# 3  Neither agree nor disagree  Neither agree nor disagree
# 4              Agree strongly                       Agree
# 5              Agree strongly              Agree strongly
# 6                       Agree                       Agree
# 7                    Disagree                       Agree
# 8                       Agree                       Agree
# 9  Neither agree nor disagree  Neither agree nor disagree
#
#                      forgrel5                    mnntpowr           unionsa  \
# 0                       Agree  Neither agree nor disagree  Yes, trade union
# 1                    Disagree                       Agree                No
# 2              Agree strongly              Agree strongly  Yes, trade union
# 3                    Disagree  Neither agree nor disagree                No
# 4              Agree strongly              Agree strongly                No
# 5              Agree strongly                       Agree                No
# 6                       Agree  Neither agree nor disagree                No
# 7           Disagree strongly              Agree strongly                No
# 8                    Disagree                       Agree                No
# 9  Neither agree nor disagree  Neither agree nor disagree                No
#
#                                             reconact    natbrit     nateng  \
# 0  In paid work (or away temporarily) for at leas...  Mentioned  Mentioned
# 1                  (Doing something else) (WRITE IN)  Mentioned        NaN
# 2  In paid work (or away temporarily) for at leas...  Mentioned  Mentioned
# 3  In paid work (or away temporarily) for at leas...  Mentioned        NaN
# 4  In paid work (or away temporarily) for at leas...        NaN  Mentioned
# 5                             Looking after the home        NaN        NaN
# 6  In paid work (or away temporarily) for at leas...  Mentioned        NaN
# 7  In paid work (or away temporarily) for at leas...  Mentioned  Mentioned
# 8  In paid work (or away temporarily) for at leas...        NaN  Mentioned
# 9  In paid work (or away temporarily) for at leas...  Mentioned  Mentioned
#
#   nateuro    natscot   natwelsh natni natasia natafric
# 0     NaN        NaN        NaN   NaN     NaN      NaN
# 1     NaN  Mentioned        NaN   NaN     NaN      NaN
# 2     NaN        NaN        NaN   NaN     NaN      NaN
# 3     NaN        NaN        NaN   NaN     NaN      NaN
# 4     NaN        NaN        NaN   NaN     NaN      NaN
# 5     NaN        NaN  Mentioned   NaN     NaN      NaN
# 6     NaN        NaN        NaN   NaN     NaN      NaN
# 7     NaN        NaN        NaN   NaN     NaN      NaN
# 8     NaN        NaN        NaN   NaN     NaN      NaN
# 9     NaN        NaN        NaN   NaN     NaN      NaN

# %%
columns_list = list(df.columns.values)

# %%
columns_list
# Out:
# ['Unnamed: 0',
#  'country',
#  'househld',
#  'rsex',
#  'rage',
#  'marstat6',
#  'childhh',
#  'married',
#  'readpap',
#  'whpaper',
#  'webnews',
#  'wnwsite1',
#  'supparty',
#  'closepty',
#  'partyidn',
#  'partyid1',
#  'politics',
#  'soctrust',
#  'ecpolicy',
#  'govtrust',
#  'mpstrust',
#  'conlabdf',
#  'spend1',
#  'dole',
#  'taxspend',
#  'incomgap',
#  'ub1poor',
#  'ccbeliev',
#  'letin',
#  'miecono',
#  'micultur',
#  'reasmig',
#  'asastay',
#  'friendob',
#  'raceori3',
#  'religion',
#  'hedqual',
#  'rearnd',
#  'welffeet',
#  'forgrel1',
#  'forgrel2',
#  'forgrel4',
#  'forgrel5',
#  'mnntpowr',
#  'unionsa',
#  'reconact',
#  'natbrit',
#  'nateng',
#  'nateuro',
#  'natscot',
#  'natwelsh',
#  'natni',
#  'natasia',
#  'natafric']

# %%
for col in columns_list:
    df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1063 entries, 0 to 1062
# Data columns (total 54 columns):
# Unnamed: 0    1063 non-null category
# country       1063 non-null category
# househld      1063 non-null category
# rsex          1063 non-null category
# rage          0 non-null category
# marstat6      1063 non-null category
# childhh       1063 non-null category
# married       1063 non-null category
# readpap       1063 non-null category
# whpaper       383 non-null category
# webnews       1063 non-null category
# wnwsite1      542 non-null category
# supparty      1059 non-null category
# closepty      688 non-null category
# partyidn      976 non-null category
# partyid1      976 non-null category
# politics      1063 non-null category
# soctrust      1052 non-null category
# ecpolicy      974 non-null category
# govtrust      1057 non-null category
# mpstrust      1058 non-null category
# conlabdf      1020 non-null category
# spend1        1058 non-null category
# dole          1029 non-null category
# taxspend      1050 non-null category
# incomgap      1035 non-null category
# ub1poor       937 non-null category
# ccbeliev      1040 non-null category
# letin         1053 non-null category
# miecono       1051 non-null category
# micultur      1052 non-null category
# reasmig       547 non-null category
# asastay       1042 non-null category
# friendob      1058 non-null category
# raceori3      1063 non-null category
# religion      1058 non-null category
# hedqual       982 non-null category
# rearnd        534 non-null category
# welffeet      883 non-null category
# forgrel1      871 non-null category
# forgrel2      859 non-null category
# forgrel4      861 non-null category
# forgrel5      862 non-null category
# mnntpowr      904 non-null category
# unionsa       1060 non-null category
# reconact      1063 non-null category
# natbrit       747 non-null category
# nateng        575 non-null category
# nateuro       122 non-null category
# natscot       82 non-null category
# natwelsh      49 non-null category
# natni         7 non-null category
# natasia       21 non-null category
# natafric      6 non-null category
# dtypes: category(54)
# memory usage: 67.8 KB

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].astype(int)
df['househld'] = df['househld'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1063 entries, 0 to 1062
# Data columns (total 54 columns):
# Unnamed: 0    1063 non-null int32
# country       1063 non-null category
# househld      1063 non-null int32
# rsex          1063 non-null category
# rage          0 non-null category
# marstat6      1063 non-null category
# childhh       1063 non-null category
# married       1063 non-null category
# readpap       1063 non-null category
# whpaper       383 non-null category
# webnews       1063 non-null category
# wnwsite1      542 non-null category
# supparty      1059 non-null category
# closepty      688 non-null category
# partyidn      976 non-null category
# partyid1      976 non-null category
# politics      1063 non-null category
# soctrust      1052 non-null category
# ecpolicy      974 non-null category
# govtrust      1057 non-null category
# mpstrust      1058 non-null category
# conlabdf      1020 non-null category
# spend1        1058 non-null category
# dole          1029 non-null category
# taxspend      1050 non-null category
# incomgap      1035 non-null category
# ub1poor       937 non-null category
# ccbeliev      1040 non-null category
# letin         1053 non-null category
# miecono       1051 non-null category
# micultur      1052 non-null category
# reasmig       547 non-null category
# asastay       1042 non-null category
# friendob      1058 non-null category
# raceori3      1063 non-null category
# religion      1058 non-null category
# hedqual       982 non-null category
# rearnd        534 non-null category
# welffeet      883 non-null category
# forgrel1      871 non-null category
# forgrel2      859 non-null category
# forgrel4      861 non-null category
# forgrel5      862 non-null category
# mnntpowr      904 non-null category
# unionsa       1060 non-null category
# reconact      1063 non-null category
# natbrit       747 non-null category
# nateng        575 non-null category
# nateuro       122 non-null category
# natscot       82 non-null category
# natwelsh      49 non-null category
# natni         7 non-null category
# natasia       21 non-null category
# natafric      6 non-null category
# dtypes: category(52), int32(2)
# memory usage: 64.6 KB
